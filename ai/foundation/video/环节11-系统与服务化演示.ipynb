# %% [markdown]
# # 环节 11 · 系统与服务化（配套 Notebook）
# > 经典开源账：MiniMax-H3 Base。总揽：[环节00](./环节00-总揽与环节导航.md)
#
# > 配套：[环节11-系统与服务化详解.md](./环节11-系统与服务化详解.md)

# %%
stack = [
    ("Context-IR", "托管", "观感第一嫌疑", False),
    ("H3-Base FL2VA", "开源", "t2va/fl2va 768p", True),
    ("H3-Base Ref2VA", "开源", "参考/V2V 768p", True),
    ("Regenerate-2K", "托管", "in-context 2K", False),
    ("People LoRA", "社区", "挂 qkv，不替代 IR/Regen", True),
]
print(f"{'模块':18} {'形态':6} 本地能复现?")
for name, kind, note, local in stack:
    print(f"{name:18} {kind:6} {'是' if local else '否':8}  {note}")

dit_gb, enc_gb = 61.7, 62.1
print(f"\n只 load 一份 DiT+Encoder ≈ {dit_gb+enc_gb:.0f} GB bf16（不含KV/激活）")
print(f"两份 DiT+Encoder ≈ {2*dit_gb+enc_gb:.0f} GB")
print("比较画质时写明：768 Base vs 2K 系统。")
